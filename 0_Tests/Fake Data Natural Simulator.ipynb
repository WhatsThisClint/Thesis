# %% [markdown]
# # Fake Data Natural Simulator

# %% [markdown]
# ## Anomaly Maker

# %% [markdown]
# The introduce_anomalies function: This function takes two parameters: file_path, which is the path to the CSV file containing the groundwater time series data, and num_sites_to_consider, which is the number of unique sites to consider for introducing anomalies.
#
# Load the dataset: The function reads the CSV file specified by file_path into a pandas DataFrame df.
#
# Count unique sites: The function calculates the total number of unique sites in the dataset and prints it.
#
# Check the number of sites to consider: It checks if the num_sites_to_consider is greater than the total number of unique sites. If so, it prints a message indicating that the number of sites to consider is too high, and the function returns.
#
# Random site selection: If the num_sites_to_consider is valid, the function randomly selects num_sites_to_consider sites from the unique sites.
#
# Data modification loop: The function iterates through the selected sites. For each site, it filters the data related to that site from the DataFrame. Then, it randomly selects 25 data points and multiplies their 'level' values by a random multiplier between 2 and 6.
#
# Helper function: There is a helper function called has_max_modifications_for_year to keep track of how many data points have been modified for a given year.
#
# Display modified data: The modified data is printed on the console, showing the changes made to the original data.
#
# Save modified data: The modified data is saved to a new CSV file named "modified_groundwater_timeseries_data.csv".
#
# __name__ == "__main__" block: This block is executed only when the script is run directly (not imported as a module). It prompts the user to input the number of sites to consider for introducing anomalies and calls the introduce_anomalies function with the provided input.

# %%
import pandas as pd
import random

def introduce_anomalies(file_path, num_sites_to_consider):
    # Load the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Count the number of unique sites
    unique_sites = df['site'].unique()
    num_unique_sites = len(unique_sites)
    print(f"Total unique sites: {num_unique_sites}")

    if num_sites_to_consider > num_unique_sites:
        print("The number of sites to consider is greater than the total unique sites.")
        return

    # Randomly select sites to consider
    selected_sites = random.sample(unique_sites.tolist(), num_sites_to_consider)

    # Create a DataFrame to store the modified data
    modified_data = df.copy()

    # Helper function to check if there are already 3 modified data points for a year
    def has_max_modifications_for_year(year, modified_years):
        count = modified_years.count(year)
        return count >= 3

    modified_years = []

    for site in selected_sites:
        # Filter data for the selected site
        site_data = df[df['site'] == site]

        # Select 25 random level values and multiply them by a random number between 2 and 6
        random_indices = random.sample(range(len(site_data)), 25)
        for idx in random_indices:
            year = pd.to_datetime(site_data.iloc[idx]['date']).year
            if not has_max_modifications_for_year(year, modified_years):
                random_multiplier = random.uniform(2, 6)
                modified_data.loc[site_data.index[idx], 'level'] *= random_multiplier
                modified_years.append(year)
                print(f"Modified: Site - {site}, Date - {site_data.iloc[idx]['date']}")

    # # Display the modified data
    # modified_data = modified_data.round(2)
    # print("\nModified Data:")
    # print(modified_data[modified_data != df].dropna(how='all'))

    # Save the modified data to a new CSV file
    modified_data.to_csv("modified_groundwater_timeseries_data.csv", index=False)
    print("\nModified data has been saved to 'modified_groundwater_timeseries_data.csv'.")

if __name__ == "__main__":
    file_path = "groundwater_timeseries_data_Negative.csv"
    num_sites_to_consider = int(input("Enter the number of sites to consider for introducing anomalies: "))
    introduce_anomalies(file_path, num_sites_to_consider)
# Out:
# Enter the number of sites to consider for introducing anomalies:  255
# Total unique sites: 3200
# Modified: Site - Site_1307, Date - 2009-10-01
# Modified: Site - Site_1307, Date - 2004-12-01
# Modified: Site - Site_1307, Date - 2009-11-01
# Modified: Site - Site_1307, Date - 1986-10-01
# Modified: Site - Site_1307, Date - 1990-11-01
# Modified: Site - Site_1307, Date - 1998-11-01
# Modified: Site - Site_1307, Date - 2016-07-01
# Modified: Site - Site_1307, Date - 2018-11-01
# Modified: Site - Site_1307, Date - 2004-01-01
# Modified: Site - Site_1307, Date - 1997-02-01
# Modified: Site - Site_1307, Date - 2019-06-01
# Modified: Site - Site_1307, Date - 2017-03-01
# Modified: Site - Site_1307, Date - 2006-07-01
# Modified: Site - Site_1307, Date - 1994-08-01
# Modified: Site - Site_1307, Date - 2010-10-01
# Modified: Site - Site_1307, Date - 2008-12-01
# Modified: Site - Site_1307, Date - 2020-11-01
# Modified: Site - Site_1307, Date - 1999-10-01
# Modified: Site - Site_1307, Date - 2020-10-01
# Modified: Site - Site_1307, Date - 2005-07-01
# Modified: Site - Site_1307, Date - 2005-09-01
# Modified: Site - Site_1307, Date - 1988-10-01
# Modified: Site - Site_1307, Date - 2021-01-01
# Modified: Site - Site_1307, Date - 1986-04-01
# Modified: Site - Site_1307, Date - 2007-08-01
# Modified: Site - Site_1429, Date - 1989-05-01
# Modified: Site - Site_1429, Date - 1998-02-01
# Modified: Site - Site_1429, Date - 2002-06-01
# Modified: Site - Site_1429, Date - 2003-10-01
# Modified: Site - Site_1429, Date - 2011-03-01
# Modified: Site - Site_1429, Date - 2003-07-01
# Modified: Site - Site_1429, Date - 1997-02-01
# Modified: Site - Site_1429, Date - 2020-04-01
# Modified: Site - Site_1429, Date - 2006-02-01
# Modified: Site - Site_1429, Date - 2022-09-01
# Modified: Site - Site_1429, Date - 2009-04-01
# Modified: Site - Site_1429, Date - 1998-06-01
# Modified: Site - Site_1429, Date - 2011-08-01
# Modified: Site - Site_1429, Date - 2008-09-01
# Modified: Site - Site_1429, Date - 1988-05-01
# Modified: Site - Site_1429, Date - 2018-11-01
# Modified: Site - Site_1429, Date - 2001-03-01
# Modified: Site - Site_1429, Date - 2001-09-01
# Modified: Site - Site_1429, Date - 2022-07-01
# Modified: Site - Site_1429, Date - 2006-11-01
# Modified: Site - Site_1429, Date - 2017-03-01
# Modified: Site - Site_1429, Date - 2018-09-01
# Modified: Site - Site_1429, Date - 2022-05-01
# Modified: Site - Site_1429, Date - 2005-08-01
# Modified: Site - Site_1059, Date - 1992-09-01
# Modified: Site - Site_1059, Date - 1992-08-01
# Modified: Site - Site_1059, Date - 2001-02-01
# Modified: Site - Site_1059, Date - 2010-11-01
# Modified: Site - Site_1059, Date - 2004-07-01
# Modified: Site - Site_1059, Date - 2013-04-01
# Modified: Site - Site_1059, Date - 2003-11-01
# Modified: Site - Site_1059, Date - 1991-08-01
# Modified: Site - Site_1059, Date - 1996-04-01
# Modified: Site - Site_1059, Date - 2017-02-01
# Modified: Site - Site_1059, Date - 2013-09-01
# Modified: Site - Site_1059, Date - 2007-10-01
# Modified: Site - Site_1059, Date - 2019-12-01
# Modified: Site - Site_1059, Date - 2000-05-01
# Modified: Site - Site_1059, Date - 2016-08-01
# Modified: Site - Site_1059, Date - 1994-05-01
# Modified: Site - Site_1059, Date - 1993-06-01
# Modified: Site - Site_1059, Date - 2016-03-01
# Modified: Site - Site_1059, Date - 2007-03-01
# Modified: Site - Site_1059, Date - 2021-03-01
# Modified: Site - Site_3188, Date - 1991-12-01
# Modified: Site - Site_3188, Date - 1985-06-01
# Modified: Site - Site_3188, Date - 1990-12-01
# Modified: Site - Site_3188, Date - 1997-01-01
# Modified: Site - Site_3188, Date - 1999-05-01
# Modified: Site - Site_3188, Date - 1995-11-01
# Modified: Site - Site_3188, Date - 1993-12-01
# Modified: Site - Site_3188, Date - 2014-09-01
# Modified: Site - Site_3188, Date - 2012-05-01
# Modified: Site - Site_3188, Date - 1999-02-01
# Modified: Site - Site_3188, Date - 2019-08-01
# Modified: Site - Site_3188, Date - 2013-04-01
# Modified: Site - Site_3188, Date - 2008-09-01
# Modified: Site - Site_3188, Date - 1995-07-01
# Modified: Site - Site_3188, Date - 2014-11-01
# Modified: Site - Site_3188, Date - 2002-01-01
# Modified: Site - Site_1019, Date - 1990-09-01
# Modified: Site - Site_1019, Date - 1993-06-01
# Modified: Site - Site_1019, Date - 1986-05-01
# Modified: Site - Site_1019, Date - 1992-09-01
# Modified: Site - Site_1019, Date - 2021-10-01
# Modified: Site - Site_1019, Date - 1996-06-01
# Modified: Site - Site_1019, Date - 2012-12-01
# Modified: Site - Site_1019, Date - 1988-11-01
# Modified: Site - Site_1019, Date - 2011-06-01
# Modified: Site - Site_1019, Date - 1987-08-01
# Modified: Site - Site_1019, Date - 1991-02-01
# Modified: Site - Site_1019, Date - 1987-10-01
# Modified: Site - Site_1019, Date - 2010-02-01
# Modified: Site - Site_1019, Date - 2002-12-01
# Modified: Site - Site_1019, Date - 1996-05-01
# Modified: Site - Site_2117, Date - 2012-03-01
# Modified: Site - Site_2117, Date - 1995-10-01
# Modified: Site - Site_2117, Date - 2000-11-01
# Modified: Site - Site_2117, Date - 1994-11-01
# Modified: Site - Site_2117, Date - 1985-02-01
# Modified: Site - Site_2117, Date - 2014-08-01
# Modified: Site - Site_2117, Date - 1985-03-01
# Modified: Site - Site_21, Date - 1989-07-01
# Modified: Site - Site_21, Date - 1989-02-01
# Modified: Site - Site_21, Date - 2015-05-01
# Modified: Site - Site_1463, Date - 2000-05-01
# Modified: Site - Site_1463, Date - 1987-06-01
# Modified: Site - Site_1463, Date - 2015-06-01
# Modified: Site - Site_520, Date - 2015-02-01
#
# Modified data has been saved to 'modified_groundwater_timeseries_data.csv'.

# %% [markdown]
# ## Gap Maker

# %%
import pandas as pd
import random

def delete_random_months(df, num_years):
    # Helper function to get random months from a year
    def get_random_months():
        return random.sample(range(1, 13), random.randint(1, 3))

    selected_years = random.sample(range(1985, 2023), num_years)

    for site in df['site'].unique():
        site_data = df[df['site'] == site]
        for year in selected_years:
            months_to_delete = get_random_months()
            for month in months_to_delete:
                idx_to_delete = site_data[(site_data['date'].dt.year == year) & (site_data['date'].dt.month == month)].index
                df.loc[idx_to_delete, 'level'] = None
                print(f"Deleted level values for Site: {site}, Year: {year}, Month: {month}")

    return df

def main():
    # Load the CSV file into a DataFrame
    file_path = "modified_groundwater_timeseries_data.csv"
    df = pd.read_csv(file_path, parse_dates=['date'])

    # Count the number of unique sites
    unique_sites = df['site'].unique()
    num_unique_sites = len(unique_sites)
    print(f"Total unique sites: {num_unique_sites}")

    # Select 15% of unique sites randomly
    num_sites_to_select = int(num_unique_sites * 0.01)
    selected_sites = random.sample(unique_sites.tolist(), num_sites_to_select)

    # Select 4 random years from each of the selected sites
    num_years_per_site = 4
    df_modified = delete_random_months(df[df['site'].isin(selected_sites)], num_years_per_site)

    # Create a new DataFrame for the modified data
    modified_data = df.copy()
    modified_data.loc[df_modified.index, 'level'] = df_modified['level']

    # Save the modified data to a new CSV file
    modified_data.to_csv("MGA_GWD.csv", index=False)
    print("\nModified data has been saved to 'MGA_GWD.csv'.")

if __name__ == "__main__":
    main()
# Out:
# Total unique sites: 3200
# Deleted level values for Site: Site_31, Year: 2022, Month: 5
# Deleted level values for Site: Site_31, Year: 2022, Month: 9
# Deleted level values for Site: Site_31, Year: 2009, Month: 6
# Deleted level values for Site: Site_31, Year: 2009, Month: 3
# Deleted level values for Site: Site_31, Year: 2009, Month: 9
# Deleted level values for Site: Site_31, Year: 1990, Month: 5
# Deleted level values for Site: Site_31, Year: 1989, Month: 9
# Deleted level values for Site: Site_31, Year: 1989, Month: 2
# Deleted level values for Site: Site_31, Year: 1989, Month: 6
# Deleted level values for Site: Site_99, Year: 2022, Month: 8
# Deleted level values for Site: Site_99, Year: 2009, Month: 8
# Deleted level values for Site: Site_99, Year: 1990, Month: 7
# Deleted level values for Site: Site_99, Year: 1990, Month: 12
# Deleted level values for Site: Site_99, Year: 1989, Month: 6
# Deleted level values for Site: Site_99, Year: 1989, Month: 9
# Deleted level values for Site: Site_99, Year: 1989, Month: 7
# Deleted level values for Site: Site_165, Year: 2022, Month: 3
# Deleted level values for Site: Site_165, Year: 2009, Month: 10
# Deleted level values for Site: Site_165, Year: 2009, Month: 5
# Deleted level values for Site: Site_165, Year: 2009, Month: 12
# Deleted level values for Site: Site_165, Year: 1990, Month: 12
# Deleted level values for Site: Site_165, Year: 1990, Month: 11
# Deleted level values for Site: Site_165, Year: 1990, Month: 1
# Deleted level values for Site: Site_165, Year: 1989, Month: 4
# Deleted level values for Site: Site_272, Year: 2022, Month: 9
# Deleted level values for Site: Site_272, Year: 2022, Month: 2
# Deleted level values for Site: Site_272, Year: 2009, Month: 4
# Deleted level values for Site: Site_272, Year: 1990, Month: 8
# Deleted level values for Site: Site_272, Year: 1989, Month: 12
# Deleted level values for Site: Site_272, Year: 1989, Month: 8
# Deleted level values for Site: Site_272, Year: 1989, Month: 3
# Deleted level values for Site: Site_341, Year: 2022, Month: 1
# Deleted level values for Site: Site_341, Year: 2022, Month: 9
# Deleted level values for Site: Site_341, Year: 2022, Month: 3
# Deleted level values for Site: Site_341, Year: 2009, Month: 10
# Deleted level values for Site: Site_341, Year: 1990, Month: 11
# Deleted level values for Site: Site_341, Year: 1990, Month: 10
# Deleted level values for Site: Site_341, Year: 1990, Month: 2
# Deleted level values for Site: Site_341, Year: 1989, Month: 2
# Deleted level values for Site: Site_341, Year: 1989, Month: 7
# Deleted level values for Site: Site_341, Year: 1989, Month: 1
# Deleted level values for Site: Site_371, Year: 2022, Month: 7
# Deleted level values for Site: Site_371, Year: 2022, Month: 9
# Deleted level values for Site: Site_371, Year: 2022, Month: 5
# Deleted level values for Site: Site_371, Year: 2009, Month: 9
# Deleted level values for Site: Site_371, Year: 2009, Month: 2
# Deleted level values for Site: Site_371, Year: 2009, Month: 11
# Deleted level values for Site: Site_371, Year: 1990, Month: 10
# Deleted level values for Site: Site_371, Year: 1990, Month: 4
# Deleted level values for Site: Site_371, Year: 1989, Month: 4
# Deleted level values for Site: Site_371, Year: 1989, Month: 3
# Deleted level values for Site: Site_371, Year: 1989, Month: 5
# Deleted level values for Site: Site_373, Year: 2022, Month: 7
# Deleted level values for Site: Site_373, Year: 2022, Month: 11
# Deleted level values for Site: Site_373, Year: 2009, Month: 6
# Deleted level values for Site: Site_373, Year: 2009, Month: 7
# Deleted level values for Site: Site_373, Year: 1990, Month: 12
# Deleted level values for Site: Site_373, Year: 1989, Month: 11
# Deleted level values for Site: Site_409, Year: 2022, Month: 5
# Deleted level values for Site: Site_409, Year: 2022, Month: 7
# Deleted level values for Site: Site_409, Year: 2009, Month: 7
# Deleted level values for Site: Site_409, Year: 1990, Month: 7
# Deleted level values for Site: Site_409, Year: 1990, Month: 4
# Deleted level values for Site: Site_409, Year: 1990, Month: 3
# Deleted level values for Site: Site_409, Year: 1989, Month: 9
# Deleted level values for Site: Site_432, Year: 2022, Month: 7
# Deleted level values for Site: Site_432, Year: 2022, Month: 5
# Deleted level values for Site: Site_432, Year: 2009, Month: 6
# Deleted level values for Site: Site_432, Year: 2009, Month: 11
# Deleted level values for Site: Site_432, Year: 1990, Month: 8
# Deleted level values for Site: Site_432, Year: 1990, Month: 5
# Deleted level values for Site: Site_432, Year: 1990, Month: 10
# Deleted level values for Site: Site_432, Year: 1989, Month: 2
# Deleted level values for Site: Site_432, Year: 1989, Month: 1
# Deleted level values for Site: Site_432, Year: 1989, Month: 4
# Deleted level values for Site: Site_433, Year: 2022, Month: 4
# Deleted level values for Site: Site_433, Year: 2022, Month: 2
# Deleted level values for Site: Site_433, Year: 2009, Month: 11
# Deleted level values for Site: Site_433, Year: 2009, Month: 4
# Deleted level values for Site: Site_433, Year: 1990, Month: 3
# Deleted level values for Site: Site_433, Year: 1990, Month: 6
# Deleted level values for Site: Site_433, Year: 1989, Month: 12
# Deleted level values for Site: Site_516, Year: 2022, Month: 9
# Deleted level values for Site: Site_516, Year: 2022, Month: 1
# Deleted level values for Site: Site_516, Year: 2022, Month: 6
# Deleted level values for Site: Site_516, Year: 2009, Month: 5
# Deleted level values for Site: Site_516, Year: 1990, Month: 12
# Deleted level values for Site: Site_516, Year: 1989, Month: 5
# Deleted level values for Site: Site_516, Year: 1989, Month: 7
# Deleted level values for Site: Site_516, Year: 1989, Month: 12
# Deleted level values for Site: Site_519, Year: 2022, Month: 2
# Deleted level values for Site: Site_519, Year: 2022, Month: 5
# Deleted level values for Site: Site_519, Year: 2009, Month: 8
# Deleted level values for Site: Site_519, Year: 2009, Month: 9
# Deleted level values for Site: Site_519, Year: 2009, Month: 3
# Deleted level values for Site: Site_519, Year: 1990, Month: 7
# Deleted level values for Site: Site_519, Year: 1990, Month: 8
# Deleted level values for Site: Site_519, Year: 1990, Month: 11
# Deleted level values for Site: Site_519, Year: 1989, Month: 7
# Deleted level values for Site: Site_645, Year: 2022, Month: 9
# Deleted level values for Site: Site_645, Year: 2009, Month: 5
# Deleted level values for Site: Site_645, Year: 2009, Month: 6
# Deleted level values for Site: Site_645, Year: 1990, Month: 10
# Deleted level values for Site: Site_645, Year: 1989, Month: 7
# Deleted level values for Site: Site_645, Year: 1989, Month: 5
# Deleted level values for Site: Site_645, Year: 1989, Month: 12
# Deleted level values for Site: Site_938, Year: 2022, Month: 8
# Deleted level values for Site: Site_938, Year: 2022, Month: 5
# Deleted level values for Site: Site_938, Year: 2022, Month: 3
# Deleted level values for Site: Site_938, Year: 2009, Month: 10
# Deleted level values for Site: Site_938, Year: 2009, Month: 8
# Deleted level values for Site: Site_938, Year: 1990, Month: 8
# Deleted level values for Site: Site_938, Year: 1990, Month: 1
# Deleted level values for Site: Site_938, Year: 1990, Month: 7
# Deleted level values for Site: Site_938, Year: 1989, Month: 11
# Deleted level values for Site: Site_938, Year: 1989, Month: 4
# Deleted level values for Site: Site_1045, Year: 2022, Month: 4
# Deleted level values for Site: Site_1045, Year: 2022, Month: 3
# Deleted level values for Site: Site_1045, Year: 2022, Month: 1
# Deleted level values for Site: Site_1045, Year: 2009, Month: 12
# Deleted level values for Site: Site_1045, Year: 2009, Month: 10
# Deleted level values for Site: Site_1045, Year: 2009, Month: 4
# Deleted level values for Site: Site_1045, Year: 1990, Month: 6
# Deleted level values for Site: Site_1045, Year: 1989, Month: 12
# Deleted level values for Site: Site_1263, Year: 2022, Month: 8
# Deleted level values for Site: Site_1263, Year: 2022, Month: 3
# Deleted level values for Site: Site_1263, Year: 2009, Month: 2
# Deleted level values for Site: Site_1263, Year: 1990, Month: 5
# Deleted level values for Site: Site_1263, Year: 1989, Month: 10
# Deleted level values for Site: Site_1263, Year: 1989, Month: 1
# Deleted level values for Site: Site_1263, Year: 1989, Month: 5
# Deleted level values for Site: Site_1269, Year: 2022, Month: 10
# Deleted level values for Site: Site_1269, Year: 2009, Month: 11
# Deleted level values for Site: Site_1269, Year: 2009, Month: 1
# Deleted level values for Site: Site_1269, Year: 1990, Month: 9
# Deleted level values for Site: Site_1269, Year: 1990, Month: 8
# Deleted level values for Site: Site_1269, Year: 1990, Month: 12
# Deleted level values for Site: Site_1269, Year: 1989, Month: 2
# Deleted level values for Site: Site_1637, Year: 2022, Month: 8
# Deleted level values for Site: Site_1637, Year: 2009, Month: 5
# Deleted level values for Site: Site_1637, Year: 2009, Month: 4
# Deleted level values for Site: Site_1637, Year: 2009, Month: 8
# Deleted level values for Site: Site_1637, Year: 1990, Month: 4
# Deleted level values for Site: Site_1637, Year: 1990, Month: 3
# Deleted level values for Site: Site_1637, Year: 1989, Month: 10
# Deleted level values for Site: Site_1921, Year: 2022, Month: 11
# Deleted level values for Site: Site_1921, Year: 2022, Month: 5
# Deleted level values for Site: Site_1921, Year: 2022, Month: 3
# Deleted level values for Site: Site_1921, Year: 2009, Month: 11
# Deleted level values for Site: Site_1921, Year: 1990, Month: 5
# Deleted level values for Site: Site_1921, Year: 1989, Month: 8
# Deleted level values for Site: Site_1921, Year: 1989, Month: 9
# Deleted level values for Site: Site_2149, Year: 2022, Month: 10
# Deleted level values for Site: Site_2149, Year: 2009, Month: 8
# Deleted level values for Site: Site_2149, Year: 1990, Month: 9
# Deleted level values for Site: Site_2149, Year: 1989, Month: 4
# Deleted level values for Site: Site_2149, Year: 1989, Month: 3
# Deleted level values for Site: Site_2149, Year: 1989, Month: 9
# Deleted level values for Site: Site_2290, Year: 2022, Month: 5
# Deleted level values for Site: Site_2290, Year: 2022, Month: 10
# Deleted level values for Site: Site_2290, Year: 2022, Month: 9
# Deleted level values for Site: Site_2290, Year: 2009, Month: 11
# Deleted level values for Site: Site_2290, Year: 2009, Month: 1
# Deleted level values for Site: Site_2290, Year: 2009, Month: 6
# Deleted level values for Site: Site_2290, Year: 1990, Month: 2
# Deleted level values for Site: Site_2290, Year: 1990, Month: 8
# Deleted level values for Site: Site_2290, Year: 1990, Month: 12
# Deleted level values for Site: Site_2290, Year: 1989, Month: 5
# Deleted level values for Site: Site_2290, Year: 1989, Month: 10
# Deleted level values for Site: Site_2321, Year: 2022, Month: 11
# Deleted level values for Site: Site_2321, Year: 2022, Month: 9
# Deleted level values for Site: Site_2321, Year: 2022, Month: 3
# Deleted level values for Site: Site_2321, Year: 2009, Month: 3
# Deleted level values for Site: Site_2321, Year: 1990, Month: 3
# Deleted level values for Site: Site_2321, Year: 1989, Month: 1
# Deleted level values for Site: Site_2321, Year: 1989, Month: 9
# Deleted level values for Site: Site_2321, Year: 1989, Month: 7
# Deleted level values for Site: Site_2595, Year: 2022, Month: 1
# Deleted level values for Site: Site_2595, Year: 2022, Month: 11
# Deleted level values for Site: Site_2595, Year: 2022, Month: 12
# Deleted level values for Site: Site_2595, Year: 2009, Month: 4
# Deleted level values for Site: Site_2595, Year: 2009, Month: 2
# Deleted level values for Site: Site_2595, Year: 1990, Month: 3
# Deleted level values for Site: Site_2595, Year: 1990, Month: 1
# Deleted level values for Site: Site_2595, Year: 1990, Month: 11
# Deleted level values for Site: Site_2595, Year: 1989, Month: 1
# Deleted level values for Site: Site_2595, Year: 1989, Month: 9
# Deleted level values for Site: Site_2639, Year: 2022, Month: 5
# Deleted level values for Site: Site_2639, Year: 2022, Month: 3
# Deleted level values for Site: Site_2639, Year: 2022, Month: 7
# Deleted level values for Site: Site_2639, Year: 2009, Month: 3
# Deleted level values for Site: Site_2639, Year: 2009, Month: 1
# Deleted level values for Site: Site_2639, Year: 1990, Month: 5
# Deleted level values for Site: Site_2639, Year: 1990, Month: 12
# Deleted level values for Site: Site_2639, Year: 1990, Month: 10
# Deleted level values for Site: Site_2639, Year: 1989, Month: 11
# Deleted level values for Site: Site_2675, Year: 2022, Month: 2
# Deleted level values for Site: Site_2675, Year: 2022, Month: 3
# Deleted level values for Site: Site_2675, Year: 2009, Month: 3
# Deleted level values for Site: Site_2675, Year: 1990, Month: 12
# Deleted level values for Site: Site_2675, Year: 1990, Month: 6
# Deleted level values for Site: Site_2675, Year: 1989, Month: 7
# Deleted level values for Site: Site_2675, Year: 1989, Month: 1
# Deleted level values for Site: Site_2675, Year: 1989, Month: 4
# Deleted level values for Site: Site_2729, Year: 2022, Month: 12
# Deleted level values for Site: Site_2729, Year: 2009, Month: 5
# Deleted level values for Site: Site_2729, Year: 1990, Month: 1
# Deleted level values for Site: Site_2729, Year: 1989, Month: 3
# Deleted level values for Site: Site_2729, Year: 1989, Month: 1
# Deleted level values for Site: Site_2819, Year: 2022, Month: 6
# Deleted level values for Site: Site_2819, Year: 2009, Month: 7
# Deleted level values for Site: Site_2819, Year: 1990, Month: 1
# Deleted level values for Site: Site_2819, Year: 1990, Month: 3
# Deleted level values for Site: Site_2819, Year: 1989, Month: 5
# Deleted level values for Site: Site_2819, Year: 1989, Month: 7
# Deleted level values for Site: Site_2819, Year: 1989, Month: 8
# Deleted level values for Site: Site_2823, Year: 2022, Month: 4
# Deleted level values for Site: Site_2823, Year: 2009, Month: 9
# Deleted level values for Site: Site_2823, Year: 1990, Month: 5
# Deleted level values for Site: Site_2823, Year: 1990, Month: 2
# Deleted level values for Site: Site_2823, Year: 1989, Month: 2
# Deleted level values for Site: Site_2823, Year: 1989, Month: 7
# Deleted level values for Site: Site_2869, Year: 2022, Month: 1
# Deleted level values for Site: Site_2869, Year: 2022, Month: 10
# Deleted level values for Site: Site_2869, Year: 2022, Month: 4
# Deleted level values for Site: Site_2869, Year: 2009, Month: 12
# Deleted level values for Site: Site_2869, Year: 2009, Month: 6
# Deleted level values for Site: Site_2869, Year: 1990, Month: 4
# Deleted level values for Site: Site_2869, Year: 1990, Month: 2
# Deleted level values for Site: Site_2869, Year: 1989, Month: 12
# Deleted level values for Site: Site_2896, Year: 2022, Month: 2
# Deleted level values for Site: Site_2896, Year: 2009, Month: 1
# Deleted level values for Site: Site_2896, Year: 1990, Month: 11
# Deleted level values for Site: Site_2896, Year: 1989, Month: 2
# Deleted level values for Site: Site_2896, Year: 1989, Month: 12
# Deleted level values for Site: Site_3018, Year: 2022, Month: 2
# Deleted level values for Site: Site_3018, Year: 2022, Month: 12
# Deleted level values for Site: Site_3018, Year: 2022, Month: 3
# Deleted level values for Site: Site_3018, Year: 2009, Month: 6
# Deleted level values for Site: Site_3018, Year: 2009, Month: 1
# Deleted level values for Site: Site_3018, Year: 2009, Month: 4
# Deleted level values for Site: Site_3018, Year: 1990, Month: 2
# Deleted level values for Site: Site_3018, Year: 1990, Month: 8
# Deleted level values for Site: Site_3018, Year: 1989, Month: 1
# Deleted level values for Site: Site_3018, Year: 1989, Month: 3
# Deleted level values for Site: Site_3018, Year: 1989, Month: 4
# Deleted level values for Site: Site_3153, Year: 2022, Month: 5
# Deleted level values for Site: Site_3153, Year: 2022, Month: 3
# Deleted level values for Site: Site_3153, Year: 2022, Month: 11
# Deleted level values for Site: Site_3153, Year: 2009, Month: 7
# Deleted level values for Site: Site_3153, Year: 1990, Month: 6
# Deleted level values for Site: Site_3153, Year: 1990, Month: 10
# Deleted level values for Site: Site_3153, Year: 1989, Month: 9
# Deleted level values for Site: Site_3153, Year: 1989, Month: 4
#
# Modified data has been saved to 'MGA_GWD.csv'.

# %% [markdown]
# ## Checker

# %%
import pandas as pd

def find_missing_values(df):
    missing_values = df[df['level'].isnull()]
    print(f"\nTotal missing level values: {len(missing_values)}")
    if not missing_values.empty:
        print("\nMissing level values:")
        print(missing_values[['site', 'date']])

def find_anomalies(df):
    def is_anomaly(series):
        # Assuming anomalies are values below a certain threshold (e.g., -100)
        threshold = -100
        return series < threshold

    anomalies = df.groupby('site')['level'].apply(is_anomaly)
    anomaly_dates = df[anomalies].dropna()
    print("\nAnomaly dates and level values:")
    print(anomaly_dates[['site', 'date', 'level']])

def main():
    # Load the CSV file into a DataFrame
    file_path = "MGA_GWD.csv"
    df = pd.read_csv(file_path, parse_dates=['date'])

    # Find missing values
    find_missing_values(df)

    # Find anomalies
    find_anomalies(df)

if __name__ == "__main__":
    main()
# Out:
# Total missing level values: 254
#
# Missing level values:
#               site       date
# 13729      Site_31 1989-02-01
# 13733      Site_31 1989-06-01
# 13736      Site_31 1989-09-01
# 13744      Site_31 1990-05-01
# 13970      Site_31 2009-03-01
# ...            ...        ...
# 1437381  Site_3153 1990-10-01
# 1437606  Site_3153 2009-07-01
# 1437758  Site_3153 2022-03-01
# 1437760  Site_3153 2022-05-01
# 1437766  Site_3153 2022-11-01
#
# [254 rows x 2 columns]
# C:\Users\cfe004\AppData\Local\Temp\ipykernel_18576\1201289748.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   anomaly_dates = df[anomalies].dropna()
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[51], line 33
#      30     find_anomalies(df)
#      32 if __name__ == "__main__":
# ---> 33     main()
#
# Cell In[51], line 30, in main()
#      27 find_missing_values(df)
#      29 # Find anomalies
# ---> 30 find_anomalies(df)
#
# Cell In[51], line 17, in find_anomalies(df)
#      14     return series < threshold
#      16 anomalies = df.groupby('site')['level'].apply(is_anomaly)
# ---> 17 anomaly_dates = df[anomalies].dropna()
#      18 print("\nAnomaly dates and level values:")
#      19 print(anomaly_dates[['site', 'date', 'level']])
#
# File ~\AppData\Local\miniconda3\envs\thesis\Lib\site-packages\pandas\core\frame.py:3752, in DataFrame.__getitem__(self, key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
# -> 3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#    3756 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~\AppData\Local\miniconda3\envs\thesis\Lib\site-packages\pandas\core\frame.py:3805, in DataFrame._getitem_bool_array(self, key)
#    3799     raise ValueError(
#    3800         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3801     )
#    3803 # check_bool_indexer will throw exception if Series key cannot
#    3804 # be reindexed to match DataFrame rows
# -> 3805 key = check_bool_indexer(self.index, key)
#    3807 if key.all():
#    3808     return self.copy(deep=None)
#
# File ~\AppData\Local\miniconda3\envs\thesis\Lib\site-packages\pandas\core\indexing.py:2506, in check_bool_indexer(index, key)
#    2504 indexer = result.index.get_indexer_for(index)
#    2505 if -1 in indexer:
# -> 2506     raise IndexingError(
#    2507         "Unalignable boolean Series provided as "
#    2508         "indexer (index of the boolean Series and of "
#    2509         "the indexed object do not match)."
#    2510     )
#    2512 result = result.take(indexer)
#    2514 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
